# %%
upper_edge = 10
lower_edge = 20
height = 5

s = (upper_edge+lower_edge) * height /2

print(f"上辺：{upper_edge}cm")
print(f"下辺：{lower_edge}cm")
print(f"高さ：{height}cm")
print(f"面積：{s}cm²")
# Out:
# 上辺：10cm
# 下辺：20cm
# 高さ：5cm
# 面積：75.0cm²
